# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
def limitesEjes():
    #plt.axis([x1,x2,y1,y2])
    plt.axis([0,200,0,200])
    plt.grid(True)
    plt.title('Gráfica de Puntos')

# %%
limitesEjes()

#================ Diseñar una linea ==========
for x in np.arange(50,175,0.1):
    for y in np.arange(20,21,6):
        
        #plt.scatter(x(array), y(array), s(tamaño) color, etc))
        plt.scatter(x, y, s=2, color='b')#k is black / b is blue

# %%
def generateLines():
    for x in np.arange(x1,x2,1):
        for y in np.arange(y1,y2,1):
            plt.scatter(x, y, s=2, color='b')#k is black / b is blue

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-46e627c4a1a0> in <module>
#       1 limitesEjes()
# ----> 2 generateLines(50,175,20,21)
#
# TypeError: generateLines() takes 0 positional arguments but 4 were given
