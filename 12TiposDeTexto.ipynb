# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x1=0
x2=100
y1=0
y2=100

plt.axis([x1,x2,y1,y2])
#plt.axis('on')

plt.grid(True)

plt.title('Ejemplos de Textos')

#plt.text(x,y,'text',color='color ',size='size',fontweight='fontweight '
#,fontstyle='fontstyle',rotation=degrees)

plt.text(20,80,'Texto Pequeño',size='small')

plt.text(20,70,'Texto Normal')

plt.text(20,60,'Texto Grande', size='large')

plt.text(20,50,'Texto Grande en Negrita', size='large', fontweight='bold')

plt.text(20,40,'Texto Grande en Cursiva', size='large', fontstyle='italic')

plt.text(20,40,'Texto Grande en Cursiva Color Verde', size='large'
         , fontstyle='italic', color='green')

plt.text(20,30,'Texto Grande en Cursiva Color Verde', size='large'
         , fontstyle='italic', color='blue', rotation=300)


plt.text(20,20,'F(x)=2X+8', size='large'
         , fontstyle='italic')
# Out:
# Text(20, 20, 'F(x)=2X+8')
